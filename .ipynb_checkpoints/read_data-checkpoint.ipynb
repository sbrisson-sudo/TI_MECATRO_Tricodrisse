# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


# %matplotlib notebook

# %%
data = pd.read_csv("courbes_pour_analyse.txt", delimiter = ' ')

# %%
data
# Out:
#        Timestamp(ms)  actualVelocity_1  actualVelocity_2  v_target_mobile  \
# 0                 10                 0                -1         0.000000
# 1                 30                -3                -4         0.000000
# 2                 49                 0                -5         0.000000
# 3                 70                -2                -4         0.000000
# 4                 90                 0                -7         0.000000
# ...              ...               ...               ...              ...
# 10500         358030                22                 2        -0.023597
# 10501         358050                63                 0        -0.023597
# 10502         358070                 4                -2        -0.023597
# 10503         358090                -4                 2        -0.023597
# 10504         358110                -3                 1        -0.023597
#
#        asserv.v_mobile  asserv.alpha  targetVelocity_1  targetVelocity_2  \
# ...

# %%
np.max(data['h_triangle']) - np.min(data['h_triangle'][data['h_triangle'] != 0])
# Out:
# 0.07359850406646729

# %% [markdown]
# 1.5 cm de variation pour h est acceptable( problème quand on va voir la courbe on voit que c'est que une augmentation)

# %%
plt.plot(data['Timestamp(ms)'], data[['x', 'initial_x', 'asserv.target_x', 'h_triangle']], label = ('x', 'initial_x', 'target_x', 'h_triangle'))
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.plot(data['Timestamp(ms)'][::10], data[['v_target_mobile']][::10], label = ('v_target_mobile'))
v_mobile = data['targetVelocity_1']* 0.0575 *(2 * np.pi) * (data['x']**2 + data['h_triangle']**2)**(1/2)/ 648/data['x']



plt.plot(data['Timestamp(ms)'][::10], v_mobile[::10] , label = 'v_mobile réelle')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.plot(data['Timestamp(ms)'][::10], data[['targetVelocity_1', 'targetVelocity_2', 'actualVelocity_1', 'actualVelocity_2']][::10], label = ('targetVelocity_1', 'targetVelocity_2', 'actualVelocity_1', 'actualVelocity_2'))
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
