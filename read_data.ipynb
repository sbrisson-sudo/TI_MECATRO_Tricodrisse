# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


# %matplotlib notebook

# %%
data = pd.read_csv("3_x_target_changev.txt", delimiter = ' ')

# %%
data
# Out:
#       Timestamp(ms)  actualVelocity_1  actualVelocity_2  v_target_mobile  \
# 0                 4                 1                 3         0.000000
# 1                24                -3                 1         0.000000
# 2                44                -4                 3         0.000000
# 3                64                 0                -1         0.000000
# 4                84                -1                -3         0.000000
# ...             ...               ...               ...              ...
# 6041         220064               -63                 4         0.097466
# 6042         220084               -44                -4         0.097466
# 6043         220104               -10                -4         0.097466
# 6044         220124                -5                -3         0.097466
# 6045         220144                 0                -7         0.097466
#
#       asserv.v_mobile  asserv.alpha  targetVelocity_1  targetVelocity_2  \
# ...

# %%
np.max(data['h_triangle']) - np.min(data['h_triangle'][data['h_triangle'] != 0])
# Out:
# 0.015574455261230469

# %%
plt.plot(data['Timestamp(ms)'], data[['x', 'init_x', 'target_x', 'h_triangle']], label = ('x', 'init_x', 'target_x', 'h_triangle'))
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.plot(data['Timestamp(ms)'][::10], data[['v_target_mobile', 'asserv.v_mobile']][::10], label = ('v_target_mobile', 'asserv.v_mobile'))
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.plot(data['Timestamp(ms)'][::10], data[['targetVelocity_1', 'targetVelocity_2', 'actualVelocity_1', 'actualVelocity_2']][::10], label = ('targetVelocity_1', 'targetVelocity_2', 'actualVelocity_1', 'actualVelocity_2'))
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
